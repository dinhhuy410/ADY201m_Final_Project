# %%
import sys, os
sys.path.insert(0, os.path.dirname(os.getcwd()))

from load_data import load_vcb_data

import pandas as pd
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %matplotlib inline
import joblib

df = load_vcb_data()

print(f"📊 Dữ liệu: {df.shape}")
print(f"Columns: {list(df.columns)}")
print(f"Date range: {df.index[0]} → {df.index[-1]}")
# Out:
# 2026-07-24 01:12:17.250 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 📊 Dữ liệu: (1653, 10)
# Columns: ['Close', 'High', 'Low', 'Open', 'Volume', 'RSI', 'MA10', 'MA20', 'MA50', 'MACD']
# Date range: 2020-03-11 00:00:00 → 2026-07-23 00:00:00
# D:\AdyFinal\database.py:142: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)
